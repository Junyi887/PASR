# %%
import numpy

idx1 = [80, 84, 88, 92, 96, 100, 104, 108, 112, 116, 120, 124, 128, 132, 136, 140, 144, 148,
  152, 156, 160]

idx2 = [80, 82, 84, 86, 88, 90, 92, 94, 96, 98, 100, 102, 104, 106, 108, 110, 112, 114,
  116, 118, 120, 122, 124, 126, 128, 130, 132, 134, 136, 138, 140, 142, 144, 146, 148, 150,
  152, 154, 156, 158, 160]

idx3 = [80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97,
           98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115,
           116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133,
           134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151,
           152, 153, 154, 155, 156, 157, 158, 159, 160]


err1 = [0.02194624, 0.02374679, 0.02777149, 0.03280025, 0.03848243, 0.04442642,
 0.05037237, 0.05627987, 0.0622357, 0.06833929, 0.07471021, 0.08144099,
 0.08843018, 0.0958132, 0.10371497, 0.11228407, 0.12153839, 0.13133043,
 0.14167738, 0.15269206, 0.16427596]

err2 = [0.02194624, 0.02237774, 0.02374679, 0.02561612, 0.02777149, 0.03019129,
 0.03280025, 0.03558392, 0.03848243, 0.04142784, 0.04442642, 0.04740812,
 0.05037237, 0.05331627, 0.05627987, 0.05923256, 0.0622357, 0.06524653,
 0.06833929, 0.07148858, 0.07471021, 0.07802283, 0.08144099, 0.08488473,
 0.08843018, 0.09207222, 0.0958132, 0.0996901, 0.10371497, 0.10791086,
 0.11228407, 0.11683469, 0.12153839, 0.12634465, 0.13133043, 0.13644919,
 0.14167738, 0.1470964, 0.15269206, 0.15839194, 0.16427596]

err3 = [0.02194624, 0.02201176, 0.02237103, 0.02297474, 0.02374606, 0.02464288,
 0.02561038, 0.02665521, 0.02776597, 0.02892936, 0.03017681, 0.0314564,
 0.03278781, 0.0341524, 0.03556364, 0.03701261, 0.03846265, 0.03991136,
 0.04140431, 0.04289295, 0.04440313, 0.04588545, 0.04738434, 0.04885791,
 0.05033858, 0.05181584, 0.05329473, 0.05477602, 0.05625706, 0.05772604,
 0.05921761, 0.06070045, 0.0621961, 0.06370221, 0.06522598, 0.06675752,
 0.06831809, 0.06988428, 0.07147165, 0.07306682, 0.07468345, 0.07633708,
 0.07799973, 0.07969566, 0.08141745, 0.08313655, 0.08488023, 0.08663098,
 0.08840675, 0.09022117, 0.09205639, 0.0939181, 0.09580032, 0.09772224,
 0.09967083, 0.10167282, 0.10370529, 0.10577522, 0.10789389, 0.11004,
 0.1122529, 0.11450458, 0.11679225, 0.11912223, 0.12150154, 0.12388699,
 0.12631021, 0.12878443, 0.13129717, 0.1338193, 0.13639878, 0.13899766,
 0.14161482, 0.14429389, 0.14702968, 0.14982529, 0.15262151, 0.15546986,
 0.15832879, 0.16125742, 0.16420755]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
plt.scatter(idx1, err1, label='dt = 0.08',alpha=0.5,color='r')
plt.scatter(idx2, err2, label='dt = 0.04',alpha=0.4,color ='b')
plt.scatter(idx3, err3, label='dt = 0.02',alpha=0.2,color ='g')
plt.vlines(idx1,err1,0,linestyles='dashed',alpha=0.5,colors='r')
plt.vlines(idx2,err2,0,linestyles='dashed',alpha=0.5,colors='b')
plt.vlines(idx3,err3,0,linestyles='dashed',alpha=0.5,colors='g')
plt.xlabel('Time index')
plt.ylabel('Error')
plt.ylim(0)
plt.legend()

# %%
h = 0.001
task_Dt = 4.0
task_Dt//2
h = task_dt / Total_ode_steps
def dt_008():
    for ode_step in (8):
        z1 = z0 + h*self.ode(z0)
        z0 = z1
    return z0

def dt_004():
    for n in (2):
        for ode_step in (4):
            z1 = z0 + h*self.ode(z0)
            z0 = z1
    return z0

y1 = dt_008()
y2 = dt_004()

if y1 != y2:
    print("wrong")
